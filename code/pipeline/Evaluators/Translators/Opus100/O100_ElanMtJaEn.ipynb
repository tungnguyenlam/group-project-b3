# %%
import os
import sys

ENDWITHS = 'Opus100'

NOTEBOOK_DIR = os.getcwd()

if not NOTEBOOK_DIR.endswith(ENDWITHS):
    raise ValueError(f"Not in correct dir, expect end with {ENDWITHS}, but got {NOTEBOOK_DIR} instead")

BASE_DIR = os.path.abspath(os.path.join(NOTEBOOK_DIR, '..', '..', '..', '..', '..'))
print(BASE_DIR)

sys.path.insert(0, os.path.join(BASE_DIR, 'code'))
# Out:
# /Volumes/HP_P900/Users/tungnguyen/Library/CloudStorage/GoogleDrive-nguyenlamtungthptltt@gmail.com/My Drive/Projects-Large/Group-Project-B3/code-just-to-preview/group-project-b3

# %%
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"

import torch
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
from Opus100Evaluator import Opus100Evaluator
from pipeline.TranslationModels.ElanMtJaEnBatchTranslator import ElanMtJaEnBatchTranslator

# %%
evaluator = Opus100Evaluator()

translation_model = ElanMtJaEnBatchTranslator()
translation_model.load_model(device=device, elan_model='base')

metrics = evaluator.evaluate(translation_model, batch_size=10, verbose=False, device=device)
# Out:
# Loading Dataset...
# Loading Mitsua/elan-mt-base-ja-en to mps...
# Model is already loaded
# Starting evaluation on mps...
#   6%|▋         | 13/200 [00:12<02:34,  1.21it/s]

# %%
print(f"CER: {metrics['cer']}, \nWER: {metrics['wer']}, \nBLEU: {metrics['bleu']}, \nCHRF: {metrics['chrf']}, \nBERTScore: {metrics['bertscore']}")
